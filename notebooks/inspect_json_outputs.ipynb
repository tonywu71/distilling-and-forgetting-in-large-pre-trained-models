# %%
import pandas as pd

# %%
df = pd.read_json("final-ami_validation-preds_normalized.json")

df["len_pred"] = df["predictions"].str.split().str.len()
df["len_ref"] = df["references"].str.split().str.len()

df = df.sort_values("len_pred", ascending=False)

# %%
df
# Out:
#                                              references  \
# 476   well it could be like mobiles that just you ju...
# 445                        so we just used the top part
# 609   well it is a trend in fashion in clothing and ...
# 884   that you can p well i see you are thinking it ...
# 1057         so we can put gisella in the 2 people room
# ...                                                 ...
# 239
# 243
# 1072                                                  2
# 1182                                               yeah
# 656
#
#                                             predictions  len_pred  len_ref
# 476   well it could be like the the the the the the ...       113       13
# 445   so we just to the to to to to to to to to to t...       112        7
# 609   well it is the the the the the the the the the...       112       11
# 884   that you can the the the the the the the the t...       112       13
# 1057  so we can to the the the the the to the to the...       112       10
# ...                                                 ...       ...      ...
# 239                                                             0        0
# 243                                                             0        0
# 1072                                                            0        1
# 1182                                                            0        1
# 656                                                             0        0
#
# [1310 rows x 4 columns]

# %%
for idx in range(5):
    print(f"Idx = {idx}")
    print("Reference: ", df.iloc[idx]["references"])
    print("Prediction: ", df.iloc[idx]["predictions"])
    print()
# Out:
# Idx = 0
# Reference:  well it could be like mobiles that just you just put a cover
# Prediction:  well it could be like the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Idx = 1
# Reference:  so we just used the top part
# Prediction:  so we just to the to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to
#
# Idx = 2
# Reference:  well it is a trend in fashion in clothing and fabrics
# Prediction:  well it is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Idx = 3
# Reference:  that you can p well i see you are thinking it is weird
# Prediction:  that you can the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Idx = 4
# Reference:  so we can put gisella in the 2 people room
# Prediction:  so we can to the the the the the to the to the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
